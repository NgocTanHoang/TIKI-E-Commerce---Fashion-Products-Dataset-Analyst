# %% [markdown]
# # Exploratory Data Analysis (EDA) - Tiki Product Data
#
# This notebook performs comprehensive exploratory data analysis on the preprocessed Tiki product data.

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import sys
import os
sys.path.append('../src')

from preprocessing import preprocess_data
from visualization import create_eda_report

# Load preprocessed data
df = preprocess_data()

print(f"Data loaded with shape: {df.shape}")
print(f"Available columns: {list(df.columns)}")
# Out:
# Starting data preprocessing...
# Loaded 6 files, total shape: (41603, 19)
# Dropped columns: ['Unnamed: 0']
# Found 3 null values
# Dropped 3 rows with null values
# Removed 27 duplicate rows
# All price relationships are consistent
# Normalized categories into main_category and sub_category
# Extracted description length feature
# Engineered discount_pct and product_age_days features
# Preprocessing complete. Final shape: (41573, 24)
# Data loaded with shape: (41573, 24)
# Available columns: ['id', 'name', 'description', 'original_price', 'price', 'fulfillment_type', 'brand', 'review_count', 'rating_average', 'favourite_count', 'pay_later', 'current_seller', 'date_created', 'number_of_images', 'vnd_cashback', 'has_video', 'category', 'quantity_sold', 'main_category', 'sub_category', 'description_length', 'discount_pct', 'product_age_days', 'composite_score']

# %% [markdown]
# ## 2. Comprehensive EDA Report
#
# Generate automated EDA visualizations and insights.

# %%
# Generate comprehensive EDA report
create_eda_report(df)
# Out:
# Generating EDA Visualization Report...
# d:\cv\DS\Business Performance & Inventory Management\notebook\../src\visualization.py:28: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=subset, x=price_col, label=category, fill=True, alpha=0.3)
# d:\cv\DS\Business Performance & Inventory Management\notebook\../src\visualization.py:28: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=subset, x=price_col, label=category, fill=True, alpha=0.3)
# d:\cv\DS\Business Performance & Inventory Management\notebook\../src\visualization.py:28: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=subset, x=price_col, label=category, fill=True, alpha=0.3)
# ...

# %% [markdown]
# ## 3. Enhanced Visualizations with Context and Interactivity
#
# This section demonstrates the optimized visualization functions with:
# - Horizontal bar charts to avoid label overlapping
# - Mean/median reference lines for context
# - Interactive Plotly charts for detailed exploration

# %%
# Import enhanced visualization functions
from visualization import (
    plot_category_performance,
    plot_interactive_price_distribution,
    plot_interactive_category_performance,
    plot_interactive_inventory_performance,
    plot_interactive_brand_comparison,
    create_interactive_eda_dashboard
)

print("Enhanced visualization functions imported successfully!")

# %% [markdown]
# ### 3.1 Enhanced Category Performance (Horizontal Bars with Context)
#
# The optimized category performance charts now use horizontal bars to avoid label overlapping and include mean/median reference lines for better context.

# %%
# Enhanced category performance with horizontal bars and context lines
plot_category_performance(df, metrics=['rating_average', 'quantity_sold', 'price'])

# %% [markdown]
# ### 3.2 Interactive Visualizations with Plotly
#
# Interactive charts allow users to hover over data points for detailed information, zoom, and explore the data dynamically.

# %%
# Interactive price distribution with hover details
plot_interactive_price_distribution(df)

# %%
# Interactive category performance comparison
plot_interactive_category_performance(df)

# %%
# Interactive inventory vs performance scatter plot
plot_interactive_inventory_performance(df)

# %%
# Interactive brand performance comparison
plot_interactive_brand_comparison(df)

# %% [markdown]
# ### 3.3 Complete Interactive EDA Dashboard
#
# Run the complete interactive dashboard for comprehensive data exploration.

# %%
# Generate complete interactive EDA dashboard
create_interactive_eda_dashboard(df)
